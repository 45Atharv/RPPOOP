# %%
class Grandfather:
    def __init__(self,name,age,work):
        self.name = name
        self.age = age
        self.work = work
        
    def description(self):
        print(f"His name is {self.name} and his age is {self.age} ,working as {self.work}")
        
    def description2(self):
        printf(f"son of {self.name}")
        
class father(Grandfather):
    def __init__(self,name,age,work):
        super().__init__(name,age,work)
        
    def description(self):
        super().description()
        
    def description2(Grandfather):
        super().description2()
        
        
class Uncle(Grandfather):
    def __init__(self,name,age,work):
        super().__init__(name,age,work)
        
    def description(self):
        super().description()
        
class son(father):
    def __init__(self,name,age,work):
        super().__init__(name,age,work)
        
    def description(self):
        super().description()
        
class daughter(father):
    def __init__(self,name,age,work):
        super().__init__(name,age,work)
        
    def description(self):
        super().description()
        
class nephew(Uncle):
    def __init__(self,name,age,work):
        super().__init__(name,age,work)
        
    def description(self):
        super().description()
        
class nephew(Uncle):
    def __init__(self,name,age,work):
        super().__init__(name,age,work)  
        
    def description(self):
        super().description()
        
aajoba = Grandfather("Baburao",90,"Advocate")
aajoba.description()
print("\n")

baba = father("Ashok",55,"Doctor")
baba.description()
print("\n")

kaka = Uncle("Vijay",58,"Advocate")
kaka.description()
print("\n")

myself = son("Atharv",19,"Student")
myself.description()
print("\n")

brother = son("Shreeshail",21,"Engineer")
brother.description()
print("\n")

cousin = nephew("Amey",27,"Advocate")
cousin.description()
print("\n")

cousin = nephew("Mihir",30,"Engineer")
cousin.description()
print("\n")
# Out:
# His name is Baburao and his age is 90 ,working as Advocate
#
#
# His name is Ashok and his age is 55 ,working as Doctor
#
#
# His name is Vijay and his age is 58 ,working as Advocate
#
#
# His name is Atharv and his age is 19 ,working as Student
#
#
# His name is Shreeshail and his age is 21 ,working as Engineer
#
#
# His name is Amey and his age is 27 ,working as Advocate
#
#
# His name is Mihir and his age is 30 ,working as Engineer
